# %%
# step1. 관련 패키지 및 모듈 불러오기
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import pandas as pd
import time

# %%
# step2. 네이버 뉴스 댓글정보 수집 함수
def get_naver_news_comments(name, wait_time=20, delay_time=0.1):
    
    # 크롬 드라이버로 해당 url에 접속
    driver = webdriver.Chrome('./chromedriver')
    
    # (크롬)드라이버가 요소를 찾는데에 최대 wait_time 초까지 기다림 (함수 사용 시 설정 가능하며 기본값은 5초)
    driver.implicitly_wait(wait_time)
    
    # 인자로 입력받은 url 주소를 가져와서 접속
    driver.get("https://www.joongang.co.kr/")
    
    #네이버 검색창 이름으로 가져오기
    search = driver.find_element_by_class_name("btn_search")
    
    #
#     search.clear()

    #검색창 열기
    search.click()
    
    #검색창 입력가능상태로만들기
    writable = driver.find_element_by_class_name("input_group")
    writable.click()
    
    #검색창에 값입력 후 검색 ~의원
    search =driver.find_element_by_class_name("form_control")
    search.send_keys(name+" 의원")
    search.send_keys(Keys.RETURN)
    
    #뉴스기사 전체보기 클릭
    driver.find_element_by_class_name("btn_full").click()
    
    #뉴스기사들어가기
    
    list_comments=[]
    
    for i in range(1,11):
        try:
            
            driver.find_element_by_xpath(f'//*[@id="container"]/section/div/section/ul/li[{i}]/div/h2/a').click()

            #댓글펼치기
            driver.find_element_by_id("comment_more").send_keys(Keys.ENTER)

            #댓글출력
            for j in range(1,11):

                try:
                    comment = driver.find_element_by_xpath(f'//*[@id="layer_comment"]/div[2]/div/ul/li[{j}]/div/div[2]/p')
                    list_comments.append(comment.text)
                except:
                    break



            driver.back()

            
        except:
            break
            
    for comment in list_comments:
        print(comment)
    
    
    
    # 키 이벤트 전송
    # 태그가 input 태그이므로 입력창에 키이벤트가 전달되면, 입력값이 자동으로 작성됨
#     search.send_keys(name+" 의원")

    # 엔터 입력
#     search.send_keys(Keys.RETURN)
    
    #뉴스탭 선택
#     continue_link = driver.find_element_by_link_text('뉴스')
    
    #뉴스탭 클릭
#     continue_link.click()
    
    #뉴스타이틀들 클래스로 가져오기
#     news_tit = driver.find_elements_by_class_name("news_tit")
    #뉴스댓글 뽑아오는 for문
#     for news in news_tit:
        #뉴스 타이틀중 하나 클릭해서 들어가기
#         switch_to.window(driver.window_handles[1]) --탭 전환하는 함수
#         news.click()
    
#         time.sleep(1)
        
#         driver.switch_to.window(driver.window_handles[1])
        
#         time.sleep(1)
        
#         driver.close()
        
#         time.sleep(1)
        
        #원래 탭으로 전환하는 함수
#         driver.switch_to.window(driver.window_handles[0])
        
#         time.sleep(3)
        
    
# step3. 실제 함수 실행 및 csv로 저장
if __name__ == '__main__': # 설명하자면 매우 길어져서 그냥 이렇게 사용하는 것을 권장
    
    # 원하는 국회의원 이름 입력
    name = '류호정'
    
    # 함수 실행
    comments = get_naver_news_comments(name)
    
    
#     # 엑셀의 첫줄에 들어갈 컬럼명
#     col = ['작성자','시간','내용']
    
#     # pandas 데이터 프레임 형태로 가공
#     df = pd.DataFrame(comments, columns=col)
    
#     # 데이터 프레임을 csv로 저장 
#     df.to_csv('news.csv')
# Out:
# 정의당이 류호정같은 이를 안짜르니까 지지율이 바닥이지
# 김원인지 뭔지 당나귀 탄 흑기사가 요즘 꽤나 설친다. 김 의원 자네 까불어 봤자 이재명이 손안에서 노는 강아지 장난감 신세 다. 날뛰고 설처가며 충성 한답시고 독고다이 자처해봤자 내년 지나고 봐 봐라. 말짱 도루묵 돼 있다. 공천을 노리는 풋수는 파장가면 개밥에 도토리 란 말아지....
# 싸워라 싸워...이참에 국회에 옥타콘을 만들어 국회의원들 끼라 한판붙어라...생중계하면 대박은 따논당상이다...ㅋ
# 10월 10일 자유통일, 주사파 저지를 위한 천만 서명 국민 대회 . 월 13시 . 광화문 광장 . / 파라솔 서명대 서명 , 인터넷 서명 국민 운동.
# 위에서 'xx'하니 아래에선 '니'라고 한다. 큰일 났다. 말들을 함부로 하고 있다. 대체로 가세가 기우려가는 집안에서 일어나는 현상이다.
# 정의당은 다음 총선에서는 자취도 없이 사라질 것이다..
# 진작에 알아 봤는 데 뭘,, 놀랍지도 않다,,,할 줄 아는 건 페미?? 지겹다, 지겨워,,,
# 당은 무슨 저게 정당이냐? 하는 일이라고는 지엽적인 문제를 큰거마냥 들고나와서 매번 헛소리나 하는 정당이... 그냥 해체해라~ 니들이 무슨 국정운영 같은게 가능하기나 한 당이냐?
# 정의당 정말 비겁하다.. 국힘도 어처구니 없지만.. 더불당은 이미 제정신이 아니고..ㅠㅠ
# 그런데 그 전에 니들이 한게 뭐 있는데.정당 맞냐? 온국민들이 쪽팔림 당할 때 그냥 무관심하지 않았나? 세비 받아 먹는거 쪽 팔리지 않나.
# 여지껏 정의당은 민주당2중대 들러리 신세 민심 잃고 추락한거 정의당 스럽게 행동 못하고 끌려가는 신세 공정 정의 없는 당은 있으나 마나
# 미국과 동맹해체를 바라는게 zM번당 놈들의 본질!오죽하면 국해의원 놈이 국가기밀을 북한 김정은 놈에게 알려줄까?그래서 미사일도 쏘게 하고!이놈들은 그저 고첩이다.대한민국 고첩들은 전라디언 플러스 경상좌익 플러스 민노총 플러스다!이 세가지 조건을 다 가지고 있는 놈들은 고조선때부터 고첩조상을 대대로 유지하는 놈들!
# 왜?2중대가!웃기지 마라.그런다고 홍워병들이 어디가겠니?영원한 더부러M번당 2중대!오죽하면 성추행도 같겠니?
# 제놈의 친형수님의 함자를 불러대며 " C.발년아 봉지를 확 찢어 버린다" 던 천하의 개 쌍.놈이 , 당사자인 제 형수님께 사과 했단 소리를 들은적 없다. 같은 상황이 오면 또 쌍욕질을 하겠다는 후랴들놈을 대선 후보로 세우고 당 대표로 뽑아놓는 괴이한 생물들이 더불어 민주당이다.
# 윤대통령과 배우자를 스토킹하며 조작질 까지 가해서 조롱하며 부지런히 지지율조작 발표 하던 개.개.끼들이 윤대통령의 초강경 반응에 놀라 ,, 제발 인정하고 사과하는 시늉이나 하고 이쯤에서 그만 두잔다..ㅋㅋ 니덜은 사람 잘못본거 같다. 윤대통령이 그럴거면 시작도 안했을 거다.. MBC더불어당.. 그리고 이재명이 ,,니덜은 J.ot됬다고 복창해라. 니덜이 알거지 되고 망하는 그날까지 국민들은 하나되어 자근자근 짓밟아 줄께.,.. OK??? Got it??? 개.새.끼들아..

# %%
""
