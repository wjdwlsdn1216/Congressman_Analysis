# %%
import pandas as pd
import numpy as np
import os

# %%
ok1 = pd.read_csv('/works/Congressman_Analysis/python_api/data/csvs/ok1.csv', encoding='utf-8')
ok2 = pd.read_csv('/works/Congressman_Analysis/python_api/data/csvs/ok2.csv', encoding='utf-8')
ok3 = pd.read_csv('/works/Congressman_Analysis/python_api/data/csvs/ok3.csv', encoding='utf-8')

# %%
ok1.drop(columns=['DETAIL_LINK','PROPOSER','MEMBER_LIST'],inplace=True)
ok2.drop(columns=['BTH_GBN_NM','TEL_NO','ASSEM_ADDR','HJ_NM','ELECT_GBN_NM','E_MAIL','SECRETARY2','SECRETARY','STAFF','HOMEPAGE','CMIT_NM','ENG_NM','JOB_RES_NM'],inplace=True)
ok3.drop(columns=['HJ_NM'],inplace=True)

# %%
ok2
# Out:
#     HG_NM    BTH_DATE POLY_NM REELE_GBN_NM  \
# 0     강기윤  1960-06-04    국민의힘           재선
# 1     강대식  1959-11-02    국민의힘           초선
# 2     강득구  1963-05-27  더불어민주당           초선
# 3     강민국  1971-03-03    국민의힘           초선
# 4     강민정  1961-04-26  더불어민주당           초선
# ..    ...         ...     ...          ...
# 294   홍익표  1967-11-20  더불어민주당           3선
# 295   홍정민  1978-11-24  더불어민주당           초선
# 296  황보승희  1976-08-05    국민의힘           초선
# 297   황운하  1962-09-10  더불어민주당           초선
# 298    황희  1967-07-28  더불어민주당           재선
#
#                                         CMITS  \
# 0                          보건복지위원회, 연금개혁특별위원회
# 1                          국토교통위원회, 예산결산특별위원회
# 2                              교육위원회, 국회운영위원회
# 3    민생경제안정특별위원회, 정무위원회, 예산결산특별위원회, 정치개혁특별위원회
# 4                              교육위원회, 국회운영위원회
# ..                                        ...
# 294                                 문화체육관광위원회
# 295                  산업통상자원중소벤처기업위원회, 여성가족위원회
# 296                                 문화체육관광위원회
# 297                                     정무위원회
# 298                        예산결산특별위원회, 외교통일위원회
#
#                                              MEM_TITLE SEX_GBN_NM   MONA_CD  \
# 0    [학력]\r\n마산공고(26회)\r\n창원대학교 행정학과\r\n중앙대학교 행정대학원...          남  14M56632
# 1    [학력]\r\n송정초등학교\r\n안심중학교\r\n경북대학교 사범대학 부속고등학교\r...          남  L2I9861C
# 2    2022. 3.  ~ 현재      더불어민주당 원내부대표 \r\n2022. 4. ...          남  8P37634C
# 3    [학력]\r\n\r\n\r\n- 봉곡초등학교 졸업(14회)\r\n\r\n- 진주중학...          남  GX22581L
# 4    현) 더불어민주당 원내소통부대표\r\n\r\n전) 21대 국회 전반기 교육위원회 \...          여  P2N50879
# ..                                                 ...        ...       ...
# 294  [학력]\r\n한양대학교 정치외교학과 졸업\r\n한양대학교 대학원 정치학 박사\r\...          남  FRN1867O
# 295  | 학력 | \r\n- 서울대학교 경제학부 졸업(2001년)\r\n- 서울대학교 경...          여  XA42275R
# 296  이화여자대학교 영어영문학\r\n영도여자고등학교\r\n\r\n(현) 제21대 국회의원...          여  J9S37905
# 297  <학력>\r\n\r\n경찰대학교 학사\r\n고려대학교대학원 행정학 석사\r\n성균관...          남  0YT3774N
# 298  2021.02~2022.05 문화체육관광부 장관\r\n2020.12~2021.02 ...          남  0VU8517U
#
#        ORIG_NM             UNITS
# 0    경남 창원시성산구        제19대, 제21대
# 1       대구 동구을              제21대
# 2    경기 안양시만안구              제21대
# 3      경남 진주시을              제21대
# 4         비례대표              제21대
# ..         ...               ...
# 294  서울 중구성동구갑  제19대, 제20대, 제21대
# 295    경기 고양시병              제21대
# 296   부산 중구영도구              제21대
# 297      대전 중구              제21대
# 298    서울 양천구갑        제20대, 제21대
#
# [299 rows x 10 columns]
